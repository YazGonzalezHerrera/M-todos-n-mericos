# %% [markdown]
# <a href="https://colab.research.google.com/github/YazGonzalezHerrera/Metodos-numericos/blob/main/M%C3%A9todo%20de%20la%20secante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

f= lambda x: np.exp(-x)-x
i=0
Tolerancia=0.000001
Error=1
a=0
b=1
while (Error>Tolerancia and i<=1000):
    xi=b-f(b)*(a-b)/(f(a)-f(b))
    Error=np.abs(f(xi))
    print('i=',i,' a=',a,' b=',b,' xi=',xi,'  f(xi)=',f(xi),' Error=',Error)
    if (f(a)-f(b))/(a-b) >0:
        b=xi
    else:
        a=xi
    i=i+1
if i>1000:
   print('Después de 1000 intentos no se logró obtener un raíz')
else:
   print('El valor de x, tal que f(x)=0 es:', xi)

x=np.linspace(-3,3,100)
plt.title('Método de la Secante')
plt.plot(x,f(x), label='f(x)', linestyle='dashed')
plt.axhline(0,color='navy')
plt.axvline(0,color='navy')
plt.axvline(xi,color='green', linestyle='dashed',label=f"f(x)=,x={xi:.6f}")
plt.xlabel('xi')
plt.ylabel('f(xi)')
plt.legend(loc='upper right')
plt.grin
plt.show()
# Out:
# i= 0  a= 0  b= 1  xi= 0.6126998367802821   f(xi)= -0.07081394787317097  Error= 0.07081394787317097
# i= 1  a= 0.6126998367802821  b= 1  xi= 0.5638383891610742   f(xi)= 0.005182354507338394  Error= 0.005182354507338394
# i= 2  a= 0.5638383891610742  b= 1  xi= 0.5673851234416811   f(xi)= -0.000378970430492398  Error= 0.000378970430492398
# i= 3  a= 0.5673851234416811  b= 1  xi= 0.5671256055485779   f(xi)= 2.7714800269529327e-05  Error= 2.7714800269529327e-05
# i= 4  a= 0.5671256055485779  b= 1  xi= 0.5671445837343684   f(xi)= -2.0268244705912153e-06  Error= 2.0268244705912153e-06
# i= 5  a= 0.5671445837343684  b= 1  xi= 0.567143195827029   f(xi)= 1.4822473226594468e-07  Error= 1.4822473226594468e-07
# El valor de x, tal que f(x)=0 es: 0.567143195827029
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-11903cec9dac> in <cell line: 33>()
# ...
